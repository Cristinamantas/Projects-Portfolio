# %%
import pandas as pd

# %%
import numpy as np

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Evolution_Datasets.csv")

# %%
#Check data that's been imported

# %%
df.head()
# Out:
#                             Genus_&_Specie      Time Location      Zone  \
# 0              hominino Orrorin tugenencin  6.041124   Africa  oriental
# 1  hominino Ardipithecus ramidus / kabadda  4.383910   Africa  oriental
# 2               Australopithecus Afarensis  3.749413   Africa  oriental
# 3               Australopithecus Anamensis  4.595606   Africa  oriental
# 4               Australopithecus Africanus  3.614060   Africa     south
#
#   Current_Country         Habitat  Cranial_Capacity     Height Incisor_Size  \
# 0           Kenya          forest         144.51410  110.24323        small
# 1        Ethiopia           mixed         293.96021  107.69018        small
# 2           Kenya           mixed         264.79849  123.76644          big
# 3           Kenya  forest-gallery         403.28047  111.40831          big
# 4    South Africa  forest-gallery         679.15233  111.59004        small
#
#   Jaw_Shape  ...             biped      Arms     Foots         Diet  \
# ...

# %%
#Clean up null values

# %%
df.isna().sum()
# Out:
# Genus_&_Specie             0
# Time                       0
# Location                   0
# Zone                       0
# Current_Country            0
# Habitat                    0
# Cranial_Capacity           0
# Height                     0
# Incisor_Size               0
# Jaw_Shape                  0
# Torus_Supraorbital         0
# Prognathism                0
# Foramen_Mágnum_Position    0
# Canine Size                0
# Canines_Shape              0
# Tooth_Enamel               0
# Tecno                      0
# Tecno_type                 0
# biped                      0
# Arms                       0
# Foots                      0
# Diet                       0
# Sexual_Dimorphism          0
# Hip                        0
# Vertical_Front             0
# Anatomy                    0
# Migrated                   0
# Skeleton                   0
# dtype: int64

# %%
#Check for duplicate values

# %%
df[df.duplicated() == True]
# Out:
# Empty DataFrame
# Columns: [Genus_&_Specie, Time, Location, Zone, Current_Country, Habitat, Cranial_Capacity, Height, Incisor_Size, Jaw_Shape, Torus_Supraorbital, Prognathism, Foramen_Mágnum_Position, Canine Size, Canines_Shape, Tooth_Enamel, Tecno, Tecno_type, biped, Arms, Foots, Diet, Sexual_Dimorphism, Hip, Vertical_Front, Anatomy, Migrated, Skeleton]
# Index: []
#
# [0 rows x 28 columns]

# %%
df.shape
# Out:
# (12000, 28)

# %%
df.dtypes
# Out:
# Genus_&_Specie              object
# Time                       float64
# Location                    object
# Zone                        object
# Current_Country             object
# Habitat                     object
# Cranial_Capacity           float64
# Height                     float64
# Incisor_Size                object
# Jaw_Shape                   object
# Torus_Supraorbital          object
# Prognathism                 object
# Foramen_Mágnum_Position     object
# Canine Size                 object
# Canines_Shape               object
# Tooth_Enamel                object
# Tecno                       object
# Tecno_type                  object
# biped                       object
# Arms                        object
# Foots                       object
# Diet                        object
# Sexual_Dimorphism           object
# Hip                         object
# Vertical_Front              object
# Anatomy                     object
# Migrated                    object
# ...

# %%
#Rename Columns: biped

# %%
df = df.rename(columns = {'biped': 'Biped'})

# %%
df.head()
# Out:
#                             Genus_&_Specie      Time Location      Zone  \
# 0              hominino Orrorin tugenencin  6.041124   Africa  oriental
# 1  hominino Ardipithecus ramidus / kabadda  4.383910   Africa  oriental
# 2               Australopithecus Afarensis  3.749413   Africa  oriental
# 3               Australopithecus Anamensis  4.595606   Africa  oriental
# 4               Australopithecus Africanus  3.614060   Africa     south
#
#   Current_Country         Habitat  Cranial_Capacity     Height Incisor_Size  \
# 0           Kenya          forest         144.51410  110.24323        small
# 1        Ethiopia           mixed         293.96021  107.69018        small
# 2           Kenya           mixed         264.79849  123.76644          big
# 3           Kenya  forest-gallery         403.28047  111.40831          big
# 4    South Africa  forest-gallery         679.15233  111.59004        small
#
#   Jaw_Shape  ...             Biped      Arms     Foots         Diet  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12000 entries, 0 to 11999
# Data columns (total 28 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Genus_&_Specie           12000 non-null  object
#  1   Time                     12000 non-null  float64
#  2   Location                 12000 non-null  object
#  3   Zone                     12000 non-null  object
#  4   Current_Country          12000 non-null  object
#  5   Habitat                  12000 non-null  object
#  6   Cranial_Capacity         12000 non-null  float64
#  7   Height                   12000 non-null  float64
#  8   Incisor_Size             12000 non-null  object
#  9   Jaw_Shape                12000 non-null  object
#  10  Torus_Supraorbital       12000 non-null  object
#  11  Prognathism              12000 non-null  object
#  12  Foramen_Mágnum_Position  12000 non-null  object
#  13  Canine Size              12000 non-null  object
# ...

# %%
df[['Cranial_Capacity', 'Height']].describe()
# Out:
#        Cranial_Capacity        Height
# count      12000.000000  12000.000000
# mean         616.824303    131.452198
# std          356.275762     24.539191
# min            0.074910     80.009030
# 25%          334.430993    112.986802
# 50%          511.320200    125.508305
# 75%          919.807697    153.877355
# max         1448.397470    184.981450

# %%
df['Genus_&_Specie'].value_counts().sort_values(ascending = False)
# Out:
# Genus_&_Specie
# hominino Orrorin tugenencin                500
# hominino Ardipithecus ramidus / kabadda    500
# Australopithecus Afarensis                 500
# Australopithecus Anamensis                 500
# Australopithecus Africanus                 500
# Homo Rodhesiensis                          500
# hominino Sahelanthropus tchadensis         500
# Homo Neanderthalensis\n                    500
# Paranthropus Aethiopicus                   500
# Homo Erectus                               500
# Homo Naledi                                500
# Homo Floresiensis                          500
# Paranthropus Boisei                        500
# Homo Rudolfensis                           500
# Homo Habilis                               500
# Homo Sapiens                               500
# Homo Antecesor                             500
# Homo Ergaster                              500
# Australopithecus Sediba                    500
# Homo Georgicus                             500
# ...

# %%
plt.figure(figsize=(12, 6))
sns.countplot(x='Current_Country', data=df,palette = 'Paired')
plt.title('Distribution of Current Country')
plt.xlabel('Current_Country')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(10, 5))
sns.histplot(df['Cranial_Capacity'], kde=False)
plt.title('Distribution of Cranial Capacity over time')
plt.xlabel('Cranial Capacity')
plt.ylabel('Frequency')
plt.xticks(rotation=45)
plt.show()
# Out:
# /Users/cristinamantas/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
plt.figure(figsize=(10, 5))
sns.histplot(df['Height'], kde=True,color='b')
plt.title('Height Distribution')
plt.xlabel('Height')
plt.ylabel('Frequency')
plt.show()
# Out:
# /Users/cristinamantas/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
plt.figure(figsize=(12, 6))
sns.countplot(x='Diet', data=df,palette = 'pastel')
plt.title('Distribution of Diet')
plt.xlabel('Diet')
plt.ylabel('Frequency')
plt.show()

# %%
colors = ['Orange', 'Purple']

# %%
plt.figure(figsize=(10,10))
sns.set(font_scale = 0.9)
plt.pie(x=df["Genus_&_Specie"].value_counts().values, autopct="%.1f%%", pctdistance=0.7,
        labels=df["Genus_&_Specie"].value_counts().index, radius=1.3-0.3, wedgeprops=dict(width=0.7))
plt.title("Subclass rates of Genus_&_Specie", fontsize=15)
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.countplot(x='Location', data=df,palette = 'pastel')
plt.title('Distribution of Location')
plt.xlabel('Location')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.countplot(x='Zone', data=df,palette = 'pastel')
plt.title('Distribution of Zone')
plt.xlabel('Zone')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.countplot(x='Habitat', data=df,palette = 'pastel')
plt.title('Distribution of Habitat')
plt.xlabel('Habitat')
plt.ylabel('Frequency')
plt.show()

# %%
#Count categorical variables for pie chart

# %%
counts_dict = {}

for column in df:
    counts_dict[column] = df[column].value_counts()

# Display the counts for each column
for column, counts in counts_dict.items():
    print(f"Counts for {column}:")
    print(counts)
    print("\n" + "="*40 + "\n")
# Out:
# Counts for Genus_&_Specie:
# Genus_&_Specie
# hominino Orrorin tugenencin                500
# hominino Ardipithecus ramidus / kabadda    500
# Paranthropus Robustus                      500
# Australopithecus Garhi                     500
# Australopithecus Bahrelghazali             500
# Homo Georgicus                             500
# Australopithecus Sediba                    500
# Homo Ergaster                              500
# Homo Antecesor                             500
# Homo Sapiens                               500
# Homo Habilis                               500
# Homo Rudolfensis                           500
# Paranthropus Boisei                        500
# Homo Floresiensis                          500
# Homo Naledi                                500
# Homo Erectus                               500
# Paranthropus Aethiopicus                   500
# Homo Neanderthalensis\n                    500
# hominino Sahelanthropus tchadensis         500
# ...

# %%
# Automatically handle all categorical columns

# %%
categorical_columns = df.select_dtypes(include=['object', 'category']).columns

# %%
for column in categorical_columns:
    counts = df[column].value_counts()

# %%
plt.figure(figsize=(6, 6))

# %%
counts.plot.pie(
    autopct='%1.1f%%',
    startangle=90,
    title=column,
    ylabel='',
)
plt.show()
